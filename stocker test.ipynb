# %%
import pkg_resources
pkg_resources.require("pandas==0.22.0")
import pandas as pd
import matplotlib.pyplot as plt
from stocker import Stockercker

# %%
microsoft = Stocker("AMZN")
# Out:
# AMZN Stocker Initialized. Data covers 1997-05-16 to 2018-03-27.
# C:\Users\Ari Bailey\Documents\RVC 18\stocker.py:72: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   self.starting_price = float(self.stock.ix[0, 'Adj. Open'])

# %%
stock_history = microsoft.stock
stock_history.head()
# Out:
#         Date   Open   High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
# 0 1997-05-16  22.38  23.75  20.50  20.75  1225000.0          0.0          1.0
# 1 1997-05-19  20.50  21.25  19.50  20.50   508900.0          0.0          1.0
# 2 1997-05-20  20.75  21.00  19.63  19.63   455600.0          0.0          1.0
# 3 1997-05-21  19.25  19.75  16.50  17.13  1571100.0          0.0          1.0
# 4 1997-05-22  17.25  17.38  15.75  16.75   981400.0          0.0          1.0
#
#    Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume         ds  \
# 0   1.865000   1.979167  1.708333    1.729167   14700000.0 1997-05-16
# 1   1.708333   1.770833  1.625000    1.708333    6106800.0 1997-05-19
# 2   1.729167   1.750000  1.635833    1.635833    5467200.0 1997-05-20
# 3   1.604167   1.645833  1.375000    1.427500   18853200.0 1997-05-21
# 4   1.437500   1.448333  1.312500    1.395833   11776800.0 1997-05-22
#
#           y  Daily Change
# 0  1.729167     -0.135833
# ...

# %%
microsoft.plot_stock()
# Out:
# Maximum Adj. Close = 1598.39 on 2018-03-12.
# Minimum Adj. Close = 1.40 on 1997-05-22.
# Current Adj. Close = 1497.05 on 2018-03-27.

# %%
model, model_data = microsoft.create_prophet_model(days=365)
# Out:
# C:\Users\Ari Bailey\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Predicted Price on 2019-03-27 = $2589.65
# C:\Users\Ari Bailey\Documents\RVC 18\stocker.py:460: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   future.ix[len(future) - 1, 'ds'].date(), future.ix[len(future) - 1, 'yhat']))

# %%
microsoft.evaluate_prediction()
# Out:
# C:\Users\Ari Bailey\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# C:\Users\Ari Bailey\Documents\RVC 18\stocker.py:524: RuntimeWarning: invalid value encountered in sign
#   test['correct'] = (np.sign(test['pred_diff']) == np.sign(test['real_diff'])) * 1
# C:\Users\Ari Bailey\Documents\RVC 18\stocker.py:541: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if (test.ix[i, 'y'] < test.ix[i, 'yhat_upper']) & (test.ix[i, 'y'] > test.ix[i, 'yhat_lower']):
# C:\Users\Ari Bailey\Documents\RVC 18\stocker.py:553: DeprecationWarning:
# .ix is deprecated. Please use
# ...

# %%
microsoft.predict_future(days=366)
# Out:
# C:\Users\Ari Bailey\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Predicted Increase:
#
#           Date     estimate     change        upper        lower
# 1   2018-03-28  1584.018852   1.933820  1609.889384  1558.914944
# 2   2018-03-29  1588.936528   4.917676  1616.601459  1562.269048
# 3   2018-03-30  1597.820582   8.884054  1623.988339  1570.631053
# 5   2018-04-01  1615.512643  17.692061  1641.647463  1587.233492
# 6   2018-04-02  1617.512714   2.000071  1644.532824  1590.965823
# 9   2018-04-05  1618.979390   3.944445  1644.054918  1591.750060
# 10  2018-04-06  1627.489544   8.510153  1653.634244  1600.876272
# 12  2018-04-08  1642.816401  15.326857  1669.623246  1616.085060
# 13  2018-04-09  1644.666993   1.850592  1671.474721  1614.586552
# ...

# %%
microsoft.changepoint_date_analysis(search=None)
# Out:
# C:\Users\Ari Bailey\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# C:\Users\Ari Bailey\Documents\RVC 18\stocker.py:727: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   c_data = train.ix[change_indices, :]
# C:\Users\Ari Bailey\Documents\RVC 18\stocker.py:747: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   print(c_data.ix[:, ['Date', 'Adj. Close', 'delta']][:5])
# ...
